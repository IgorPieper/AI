# %%
import numpy as np

# %%
a1 = np.array([1, 2, 3])
a2 = np.array([[1, 2, 3], [4, 5, 6]])

# %%
a1 > a2
# Out:
# array([[False, False, False],
#        [False, False, False]])

# %%
a2 > a1
# Out:
# array([[False, False, False],
#        [ True,  True,  True]])

# %%
a1 == a2
# Out:
# array([[ True,  True,  True],
#        [False, False, False]])
