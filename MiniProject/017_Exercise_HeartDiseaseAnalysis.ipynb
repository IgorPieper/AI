# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
heart_disease = pd.read_csv("Data/heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot(kind="hist");

# %%
fix, ax = plt.subplots()
scatter = ax.scatter(x=heart_disease["age"],
                  y=heart_disease["chol"],
                  c=heart_disease["target"])

ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol")

ax.legend(*scatter.legend_elements(), title="Target");
ax.axhline(heart_disease["chol"].mean(),
          linestyle="--")

# %%
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True)

scatter = ax0.scatter(x=heart_disease["age"],
                  y=heart_disease["chol"],
                  c=heart_disease["target"])
ax0.set(title="Heart Disease and Cholesterol Levels",
      ylabel="Cholesterol")
ax0.legend(*scatter.legend_elements(), title="Target");
ax0.axhline(heart_disease["chol"].mean(),
          linestyle="--")

scatter = ax1.scatter(x=heart_disease["age"],
                  y=heart_disease["thalach"],
                  c=heart_disease["target"])
ax1.set(title="Heart Disease and Max Heart Level",
      xlabel="Age",
      ylabel="Max Heart Level")
ax1.legend(*scatter.legend_elements(), title="Target");
ax1.axhline(heart_disease["thalach"].mean(),
          linestyle="--");

fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");
