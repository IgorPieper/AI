# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
car_sales = pd.read_csv("Data/car-sales.csv")
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$\,\.]', '', regex=True)
car_sales["Price"] = car_sales["Price"].str[:-3]
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales["Sale Date"] = pd.date_range("1/1/2025", periods=len(car_sales))
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4    400 2025-01-01          400
# 1   Honda    Red          87899      4    500 2025-01-02          900
# 2  Toyota   Blue          32549      3    700 2025-01-03         1600
# 3     BMW  Black          11179      5   2200 2025-01-04         3800
# 4  Nissan  White         213095      4    350 2025-01-05         4150
# 5  Toyota  Green          99213      4    450 2025-01-06         4600
# 6   Honda   Blue          45698      4    750 2025-01-07         5350
# 7   Honda   Blue          54738      4    700 2025-01-08         6050
# 8  Toyota  White          60000      4    625 2025-01-09         6675
# 9  Nissan  White          31600      4    970 2025-01-10         7645

# %%
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
# Short less editable version of Scatter
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# Graf from DataFrame
x = np.random.rand(10, 4)
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");
