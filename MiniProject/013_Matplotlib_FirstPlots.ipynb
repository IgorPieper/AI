# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot();
# ; at the end stoped [] from showing

# %%
x = [1, 2, 3]
plt.plot(x);

# %%
y = [-2, -4, -6]
plt.plot(x, y);

# %%
# More Shapes
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4, 5], [50, 100, 200, 250, 400]);
