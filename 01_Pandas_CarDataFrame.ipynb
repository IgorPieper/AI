# %%
import pandas as pd

# %%
brand = pd.Series(["Audi", "Ford", "Skoda"])
color = pd.Series(["Red", "Black", "White"])

# %%
zm1 = pd.DataFrame({"Brand" : brand, "Color" : color})

# %%
print(zm1)
# Out:
#    Brand  Color
# 0   Audi    Red
# 1   Ford  Black
# 2  Skoda  White
